# %% [markdown]
# <a href="https://colab.research.google.com/github/srkt331/Pandas_Practice/blob/main/Python_basics_practices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Universities.csv')

# %%
print(df)
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df['SAT'])
plt.show()

# %%
plt.hist(df['SAT'])
plt.xlabel('SAT')
plt.show()

# %%
plt.hist(df['SAT'])
plt.xlabel('SAT')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['SAT'])
plt.xlabel('SAT')
plt.ylabel('Frequency')
plt.title('Histogram of SAT')
plt.show()

# %%
import seaborn as sns

# %%
sns.histplot(df['SAT'])
# Out:
# <Axes: xlabel='SAT', ylabel='Count'>

# %%
sns.histplot(df['SAT'])
plt.show()

# %%
sns.histplot(df['Accept'])
plt.show()

# %%
sns.histplot(df['Expenses'])
plt.show()

# %%
plt.plot(df['SAT'], df['Accept'], 'rs')
plt.xlabel('SAT')
plt.ylabel('Acceptance')
plt.title('Scatterplot between SAT and Acceptance')
# Out:
# Text(0.5, 1.0, 'Scatterplot between SAT and Acceptance')

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
help(plt.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)
#     Compute and plot a histogram.
#
#     This method uses `numpy.histogram` to bin the data in *x* and count the
#     number of values in each bin, then draws the distribution either as a
#     `.BarContainer` or `.Polygon`. The *bins*, *range*, *density*, and
#     *weights* parameters are forwarded to `numpy.histogram`.
#
#     If the data has already been binned and counted, use `~.bar` or
#     `~.stairs` to plot the distribution::
#
#         counts, bins = np.histogram(x)
#         plt.stairs(counts, bins)
#
#     Alternatively, plot pre-computed bins and counts using ``hist()`` by
#     treating each bin as a single point with a weight equal to its count::
#
# ...

# %%
sns.pairplot(df)

# %%
sns.pairplot(df.iloc[:,1:4])

# %%
plt.boxplot(df['SAT'])
plt.show()

# %%
plt.boxplot(df['Accept'])
plt.xlabel('Acceptance')
plt.ylabel('Values')
plt.title('Boxplot for Accept')
plt.show()

# %%
plt.boxplot(df['Accept'], vert=False)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['SAT'])
# Out:
# <Axes: xlabel='SAT', ylabel='Density'>

# %%
sns.distplot(df['Accept'])
# Out:
# <Axes: xlabel='Accept', ylabel='Density'>

# %% [markdown]
# #**Duplicates Examples**
#
# * Create a dataframe
# * Check for duplicate values
# * Drop duplicates from dataframe
# * check the dataframe after dropping

# %%
dup=pd.DataFrame({'col1':['A','B','A','B'], 'col2':[1,2,1,2]})

# %%
dup
# Out:
#   col1  col2
# 0    A     1
# 1    B     2
# 2    A     1
# 3    B     2

# %%
dup.shape
# Out:
# (4, 2)

# %%
dup.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
dup[dup.duplicated()]
# Out:
#   col1  col2
# 2    A     1
# 3    B     2

# %%
dup1=dup.drop_duplicates()

# %%
dup1
# Out:
#   col1  col2
# 0    A     1
# 1    B     2

# %%
print(dup1)
# Out:
#   col1  col2
# 0    A     1
# 1    B     2

# %% [markdown]
# #**Numpy Arrays**

# %%
import numpy as np

# %%
a=np.array([(1,2,3,4), (4,5,6,7)])

# %%
a
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (2, 4)

# %%
a.size
# Out:
# 8

# %%
a=a.reshape(4,2)

# %%
print(a)
# Out:
# [[1 2]
#  [3 4]
#  [4 5]
#  [6 7]]

# %%
a.shape
# Out:
# (4, 2)

# %%
a = np.array([1,2,3,4])

# %%
a.shape
# Out:
# (4,)

# %%
a.min()
# Out:
# 1

# %%
a.max()
# Out:
# 4

# %%
a.sum()
# Out:
# 10

# %%
a.prod()
# Out:
# 24

# %%
a[0]
# Out:
# 1

# %%
a[2]
# Out:
# 3

# %%
a[3]
# Out:
# 4

# %%
a = np.array([(1,2,3,4),(4,5,6,7)])
a
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
a[0,1]
# Out:
# 2

# %%
a[1,1]
# Out:
# 5

# %%
a.sum(axis=0)
# Out:
# array([ 5,  7,  9, 11])

# %%
a.sum(axis=1)
# Out:
# array([10, 22])
